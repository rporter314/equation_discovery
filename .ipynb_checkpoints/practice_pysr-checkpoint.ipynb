# %% [markdown]
# # Installation of packages

# %% [markdown]
# ## install mamba

# %%
 ! mamba install -y pynco pynio pyngl
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.1.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pynco', 'pynio', 'pyngl']
#
# [+] 0.0s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 0.1s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# conda-forge/noarch   ━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 0.3s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s[+] 0.4s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━ 226.2kB /  ??.?MB @ 647.6kB/s  0.4s
# conda-forge/noarch   ╸━━━━━━━━━━━━━━━╸━━━━━━ 262.6kB /  ??.?MB @ 750.5kB/s  0.4s[+] 0.5s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━ 786.9kB /  ??.?MB @   1.7MB/s  0.5s
# conda-forge/noarch   ━━╸━━━━━━━━━━━━━━━╸━━━━ 783.5kB /  ??.?MB @   1.7MB/s  0.5s[+] 0.6s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   1.2MB /  ??.?MB @   2.2MB/s  0.6s
# conda-forge/noarch   ━━━━╸━━━━━━━━━━━━━━━╸━━   1.2MB /  ??.?MB @   2.2MB/s  0.6s[+] 0.7s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   1.8MB /  ??.?MB @   2.7MB/s  0.7s
# conda-forge/noarch   ━━━━━━╸━━━━━━━━━━━━━━━━   1.7MB /  ??.?MB @   2.6MB/s  0.7s[+] 0.8s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━   2.2MB /  ??.?MB @   3.0MB/s  0.8s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   2.1MB /  ??.?MB @   2.8MB/s  0.8s[+] 0.9s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━   2.8MB /  ??.?MB @   3.3MB/s  0.9s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   2.5MB /  ??.?MB @   2.9MB/s  0.9s[+] 1.0s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━   3.3MB /  ??.?MB @   3.5MB/s  1.0s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━   2.9MB /  ??.?MB @   3.0MB/s  1.0s[+] 1.1s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━   3.9MB /  ??.?MB @   3.7MB/s  1.1s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   3.3MB /  ??.?MB @   3.2MB/s  1.1s[+] 1.2s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━   4.3MB /  ??.?MB @   3.7MB/s  1.2s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   3.8MB /  ??.?MB @   3.3MB/s  1.2s[+] 1.3s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━   4.8MB /  ??.?MB @   3.8MB/s  1.3s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━━   4.3MB /  ??.?MB @   3.4MB/s  1.3s[+] 1.4s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   5.2MB /  ??.?MB @   3.8MB/s  1.4s
# conda-forge/noarch   ╸━━━━━━━━━━━━━━━╸━━━━━━   4.7MB /  ??.?MB @   3.5MB/s  1.4s[+] 1.5s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━

# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  32.1MB /  ??.?MB @   4.4MB/s  8.3s[+] 8.4s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  32.1MB /  ??.?MB @   4.4MB/s  8.4s[+] 8.5s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  32.1MB /  ??.?MB @   4.4MB/s  8.5s[+] 8.6s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  32.1MB /  ??.?MB @   4.4MB/s  8.6s[+] 8.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  32.2MB @   4.4MB/s Finalizing  8.7s[+] 8.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  32.2MB @   4.4MB/s Finalizing  8.8s[+] 8.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  32.2MB @   4.4MB/s Finalizing  8.9s[+] 9.0s
# [+] 9.1s
# [+] 9.2s
# [+] 9.3s
# [+] 9.4s
# [+] 9.5s
# [+] 9.6s
# [+] 9.7s
# [+] 9.8s
# [+] 9.9s
# [+] 10.0s
# [+] 10.1s
# [+] 10.2s
# [+] 10.3s
# [+] 10.4s
# conda-forge/linux-64                               @   4.4MB/s  9.0s
#
# Pinned packages:
#   - python 3.10.*
#
#
# Transaction
#
#   Prefix: /srv/conda/envs/notebook
#
#   Updating specs:
#
#    - pynco
#    - pynio
#    - pyngl
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package              Version  Build                        Channel                   Size
# ─────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────────
#
#   + g2clib               1.6.0  3                            conda-forge/linux-64      43kB
#   + gsl                    2.7  he838d99_0                   conda-forge/linux-64       3MB
#   + hdfeos2               2.20  hb955811_1002                conda-forge/linux-64     232kB
#   + hdfeos5             5.1.16  hc55c121_12                  conda-forge/linux-64     481kB
#   + ncl                  6.6.2  ha851dbf_44                  conda-forge/linux-64      57MB
#   + nco                  5.1.5  h2649ec8_0                   conda-forge/linux-64       2MB
#   + pynco                1.1.0  pyhd8ed1ab_1                 conda-forge/noarch        16kB
#   + pyngl                1.6.1  py310h25a56d0_6              conda-forge/linux-64      37MB
#   + pynio                1.5.5  py310h792da51_22             conda-forge/linux-64       5MB
#   + tempest-remap        2.1.6  h05839da_2                   conda-forge/linux-64     945kB
#   + udunits2            2.2.28  hc3e0081_0                   conda-forge/linux-64     165kB
#   + xorg-imake           1.0.7  0                            conda-forge/linux-64      23kB
#   + xorg-libxaw         1.0.14  h7f98852_1                   conda-forge/linux-64     382kB
#   + xorg-libxmu          1.1.3  h7f98852_0                   conda-forge/linux-64      93kB
#   + xorg-libxpm         3.5.13  h7f98852_0                   conda-forge/linux-64      64kB
#   + xorg-libxt           1.2.1  h7f98852_2                   conda-forge/linux-64     384kB
#   + xorg-makedepend      1.0.8  h59595ed_0                   conda-forge/linux-64      26kB
#
#   Change:
# ─────────────────────────────────────────────────────────────────────────────────────────────
#
#   - gdal                 3.6.2  py310hc1b7723_3              conda-forge
#   + gdal                 3.6.2  py310hc1b7723_7              conda-forge/linux-64       1MB
#   - geotiff              1.7.1  h7157cca_5                   conda-forge
#   + geotiff              1.7.1  h7a142b4_6                   conda-forge/linux-64     259kB
#   - libgdal              3.6.2  h10cbb15_3                   conda-forge
#   + libgdal              3.6.2  hea5766e_7                   conda-forge/linux-64      10MB
#   - libspatialite        5.0.1  h7c8129e_22                  conda-forge
#   + libspatialite        5.0.1  h221c8f1_23                  conda-forge/linux-64       4MB
#   - netcdf-fortran       4.6.0  mpi_mpich_h1e13492_2         conda-forge
#   + netcdf-fortran       4.6.0  mpi_mpich_ha3603da_3         conda-forge/linux-64     417kB
#   - parallelio          2.5.10  mpi_mpich_h862c5c2_100       conda-forge
#   + parallelio          2.5.10  mpi_mpich_h773ea27_101       conda-forge/linux-64     358kB
#
#   Upgrade:
# ─────────────────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates  2022.12.7  ha878542_0                   conda-forge
#   + ca-certificates   2023.5.7  hbcca054_0                   conda-forge/linux-64     148kB
#   - certifi          2022.12.7  pyhd8ed1ab_0                 conda-forge
#   + certifi           2023.5.7  pyhd8ed1ab_0                 conda-forge/noarch       152kB
#   - eccodes             2.28.0  h7513371_0                   conda-forge
#   + eccodes             2.29.0  h54fcba4_0                   conda-forge/linux-64       4MB
#   - esmf                 8.4.0  mpi_mpich_hc592774_104       conda-forge
#   + esmf                 8.4.1  mpi_mpich_h7b33e6e_100       conda-forge/linux-64      25MB
#   - esmpy                8.4.0  mpi_mpich_py310h515c5ea_102  conda-forge
#   + esmpy                8.4.1  pyhc1e730c_0                 conda-forge/noarch        48MB
#   - libnetcdf            4.8.1  mpi_mpich_hcd871d9_6         conda-forge
#   + libnetcdf            4.9.1  mpi_mpich_hf10a581_1         conda-forge/linux-64     810kB
#   - netcdf4              1.6.2  nompi_py310h55e1e36_100      conda-forge
#   + netcdf4              1.6.3  nompi_py310h0feb132_100      conda-forge/linux-64     490kB
#   - openssl              3.0.8  h0b41bf4_0                   conda-forge
#   + openssl              3.1.1  hd590300_1                   conda-forge/linux-64       3MB
#   - poppler            22.12.0  h091648b_1                   conda-forge
#   + poppler            23.01.0  h091648b_0                   conda-forge/linux-64      16MB
#   - proj                 9.1.0  h8ffa02c_1                   conda-forge
#   + proj                 9.1.1  h8ffa02c_2                   conda-forge/linux-64       3MB
#   - pyproj               3.4.1  py310hfc24d34_0              conda-forge
#   + pyproj               3.5.0  py310h15e2413_0              conda-forge/linux-64     447kB
#   - rasterio             1.3.4  py310hfc14bbd_0              conda-forge
#   + rasterio             1.3.6  py310h3e853a9_0              conda-forge/linux-64       7MB
#
#   Summary:
#
#   Install: 17 packages
#   Change: 6 packages
#   Upgrade: 12 packages
#
#   Total download: 231MB
#
# ─────────────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B                            0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.1s
# Downloading  (5) ━╸━━━━━━━━━━━━━━━━━━━━━   0.0 B ca-certificates            0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.2s
# Downloading  (5) ━╸━━━━━━━━━━━━━━━━━━━━━   0.0 B ca-certificates            0.1s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.3s
# Downloading  (5) ━╸━━━━━━━━━━━━━━━━━━━━━  11.4kB ca-certificates            0.2s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0sca-certificates                                    148.4kB @ 394.0kB/s  0.4s
# [+] 0.4s
# Downloading  (5) ━╸━━━━━━━━━━━━━━━━━━━━━ 476.1kB gsl                        0.3s
# Extracting   (1) ━━━━━━━━━━━╸━━━━━━━━━━━       0 ca-certificates            0.0sxorg-makedepend                                     25.6kB @  62.5kB/s  0.0s
# gsl                                                  3.4MB @   7.7MB/s  0.4s
# libnetcdf                                          810.3kB @   1.7MB/s  0.5s
# [+] 0.5s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   7.4MB eccodes                    0.4s
# Extracting   (4) ━━━━━━━━━━━━╸━━━━━━━━━━       0 ca-certificates            0.1snetcdf4                                            490.3kB @ 967.4kB/s  0.1s
# libspatialite                                        4.1MB @   7.4MB/s  0.1s
# poppler                                             15.5MB @  28.3MB/s  0.5s
# [+] 0.6s
# Downloading  (5) ━╸━━━━╸━━━━━━━━━━━━━━━━  29.2MB eccodes                    0.5s
# Extracting   (7) ━━━━━━━━━━━━━╸━━━━━━━━━       0 ca-certificates            0.2sgdal                                                 1.4MB @   2.3MB/s  0.1s
# nco                                                  1.8MB @   2.7MB/s  0.1s
# [+] 0.7s
# Downloading  (5) ━━╸━━━━━━━━━╸━━━━━━━━━━  39.2MB eccodes                    0.6s
# Extracting   (9) ━━━━━━━━━━━━━━╸━━━━━━━━       1 ca-certificates            0.3sproj                                                 2.9MB @   4.0MB/s  0.8s
# libgdal                                             10.2MB @  14.0MB/s  0.2s
# [+] 0.8s
# Downloading  (5) ━━━━╸━━━━━━━━╸━━━━━━━━━  51.0MB esmpy                      0.7s
# Extracting   (9) ╸━━━━━━╸━━━━━━━━━━━━━━━       3 gdal                       0.4shdfeos5                                            481.2kB @ 561.7kB/s  0.2s
# udunits2                                           164.6kB @ 191.7kB/s  0.1s
# eccodes                                              4.3MB @   4.9MB/s  0.4s
# [+] 0.9s
# Downloading  (5) ━━━━╸━━━━━━━━━╸━━━━━━━━  58.3MB esmpy                      0.8s
# Extracting  (10) ━╸━━━━━━━╸━━━━━━━━━━━━━       4 gdal                       0.5srasterio                                             7.3MB @   7.9MB/s  0.3s
# parallelio                                         358.2kB @ 373.4kB/s  0.1s
# xorg-libxpm                                         64.5kB @  67.2kB/s  0.1s
# tempest-remap                                      945.0kB @ 977.4kB/s  0.1s
# [+] 1.0s
# Downloading  (5) ━━━━━╸━━━━━━━━━━━━━╸━━━  68.8MB esmpy                      0.9s
# Extracting  (14) ━╸━━━━━━━━━╸━━━━━━━━━━━       4 gdal                       0.6spynco                                               16.0kB @  15.9kB/s  0.0s
# certifi                                            152.4kB @ 142.5kB/s  0.1s
# [+] 1.1s
# Downloading  (4) ━━━━━━╸━━━━━━━━━━━━━━━━  74.0MB esmpy                      1.0s
# Extracting  (14) ━━╸━━━━━━━━━━╸━━━━━━━━━       6 certifi                    0.7sgeotiff                                            258.9kB @ 240.8kB/s  0.1s
# [+] 1.2s
# Downloading  (5) ━━━━━━━╸━━━━━━━━━━━━━━━  86.7MB ncl                        1.1s
# Extracting  (15) ━━╸━━━━━━━━━━╸━━━━━━━━━       6 certifi                    0.8spyproj                                             447.1kB @ 368.5kB/s  0.1s
# [+] 1.3s
# Downloading  (5) ━━━━━━━━━━╸━━━━━━━━━━━━ 112.5MB ncl                        1.2s
# Extracting  (15) ━━━╸━━━━━━━━━━╸━━━━━━━━       7 certifi                    0.9sopenssl                                              2.6MB @   1.9MB/s  0.1s
# [+] 1.4s
# Downloading  (5) ━━━━━━━━━━━━━╸━━━━━━━━━ 140.9MB ncl                        1.3s
# Extracting  (15) ━━━━╸━━━━━━━━━━╸━━━━━━━       8 certifi                    1.0sesmf                                                24.6MB @  17.2MB/s  0.4s
# xorg-libxaw                                        382.1kB @ 266.4kB/s  0.1s
# [+] 1.5s
# Downloading  (5) ━━━━━━━━━━━━━━╸━━━━━━━━ 159.6MB ncl                        1.4s
# Extracting  (17) ━━━━━━╸━━━━━━━━━╸━━━━━━      12 eccodes                    1.1sesmpy                                               47.6MB @  31.4MB/s  0.9s
# hdfeos2                                            232.3kB @ 153.0kB/s  0.1s
# xorg-imake                                          23.4kB @  15.4kB/s  0.1s
# g2clib                                              43.0kB @  27.2kB/s  0.1s
# netcdf-fortran                                     416.5kB @ 263.9kB/s  0.1s
# [+] 1.6s
# Downloading  (4) ━━━━━━━━━━━━━━━━╸━━━━━━ 175.2MB pyngl                      1.5s
# Extracting  (15) ━━━━━━━━╸━━━━━━━━━━╸━━━      15 eccodes                    1.2sxorg-libxt                                         383.8kB @ 240.6kB/s  0.1s
# pyngl                                               36.6MB @  22.8MB/s  0.7s
# xorg-libxmu                                         92.6kB @  55.5kB/s  0.1s
# [+] 1.7s
# Downloading  (2) ━━━━━━━━━━━━━━━━╸━━━━━━ 181.2MB ncl                        1.6s
# Extracting  (17) ━━━━━━━━━╸━━━━━━━━━━━╸━      16 eccodes                    1.3spynio                                                5.2MB @   3.1MB/s  0.2s
# [+] 1.8s
# Downloading  (1) ━━━━━━━━━━━━━━━━━╸━━━━━ 187.9MB ncl                        1.7s
# Extracting  (15) ━━━━━━━━━━━╸━━━━━━━━━━━      19 eccodes                    1.4s[+] 1.9s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━╸━━━━ 192.4MB ncl                        1.8s
# Extracting  (12) ━━━━━━━━━━━━━╸━━━━━━━━━      22 esmf                       1.5s[+] 2.0s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━╸━━━━ 195.5MB ncl                        1.9s
# Extracting  (12) ━━━━━━━━━━━━━╸━━━━━━━━━      22 esmf                       1.6s[+] 2.1s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━╸━━━ 207.0MB ncl                        2.0s
# Extracting  (10) ━━━━━━━━━━━━━━╸━━━━━━━━      24 esmf                       1.7s[+] 2.2s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━╸━━ 217.3MB ncl                        2.1s
# Extracting   (6) ━━━━━━━━━━━━━━━━━╸━━━━━      28 esmf                       1.8sncl                                                 57.4MB @  25.4MB/s  1.1s
# [+] 2.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (6) ━━━━━━━━━━━━━━━━━━╸━━━━      29 esmpy                      1.9s[+] 2.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (6) ━━━━━━━━━━━━━━━━━━╸━━━━      29 esmpy                      2.0s[+] 2.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (5) ━━━━━━━━━━━━━━━━━━╸━━━━      30 esmpy                      2.1s[+] 2.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (5) ━━━━━━━━━━━━━━━━━━╸━━━━      30 esmpy                      2.2s[+] 2.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (4) ━━━━━━━━━━━━━━━━━━━╸━━━      31 ncl                        2.3s[+] 2.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (4) ━━━━━━━━━━━━━━━━━━━╸━━━      31 ncl                        2.4s[+] 2.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━╸━━      32 ncl                        2.5s[+] 3.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (3) ━━━━━━━━━━━━━━━━━━━━╸━━      32 ncl                        2.6s[+] 3.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      33 eccodes                    2.7s[+] 3.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      33 eccodes                    2.8s[+] 3.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      33 eccodes                    2.9s[+] 3.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      33 eccodes                    3.0s[+] 3.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      33 ncl                        3.1s[+] 3.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      33 ncl                        3.2s[+] 3.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      34 eccodes                    3.3s[+] 3.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      34 eccodes                    3.4s[+] 3.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      34 eccodes                    3.5s[+] 4.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 230.9MB                            2.2s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      34 eccodes                    3.6s
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## install other packages

# %%
import gcsfs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import cftime
from nco import Nco
from tqdm import tqdm
import Ngl
import xesmf as xe

# %% [markdown]
# # Import files, add time, lat, lon dims

# %%
fs = gcsfs.GCSFileSystem()

# %%
fs.ls("gs://leap-persistent-ro/sungdukyu")
# Out:
# ['leap-persistent-ro/sungdukyu/E3SM-MMF_ne4.grid-info.zarr',
#  'leap-persistent-ro/sungdukyu/E3SM-MMF_ne4.test.input.zarr',
#  'leap-persistent-ro/sungdukyu/E3SM-MMF_ne4.test.output.zarr',
#  'leap-persistent-ro/sungdukyu/E3SM-MMF_ne4.train.input.zarr',
#  'leap-persistent-ro/sungdukyu/E3SM-MMF_ne4.train.output.zarr',
#  'leap-persistent-ro/sungdukyu/testing']

# %%
mapper = fs.get_mapper('leap-persistent-ro/sungdukyu/E3SM-MMF_ne4.train.input.zarr')
ds_train_input = xr.open_dataset(mapper, engine='zarr')

# %%
ds_train_input.ymd.values[0], ds_train_input.tod.values[0]
# Out:
# (10201, 0)

# %%
# loop over all sample points
year=ds_train_input['ymd']//10000
month=ds_train_input['ymd']%10000//100
day=ds_train_input['ymd']%10000%100
hour=ds_train_input['tod']//3600
minute=ds_train_input['tod']%3600//60

k=0
t = []
for k in range(len(ds_train_input['ymd'])):
    t.append(cftime.DatetimeNoLeap(year[k],month[k],day[k],hour[k],minute[k]))

# add the time array to the 'sample' dimension; then, rename
ds_train_input['sample'] = t
ds_train_input = ds_train_input.rename({'sample':'time'})

# now 'time' dimension replaced 'sample' dimension.
ds_train_input = ds_train_input.drop(['tod','ymd'])

# Check the current **time** dimension, read the timestep
ds_train_input.time.values[0:5]
# Out:
# array([cftime.DatetimeNoLeap(1, 2, 1, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1, 2, 1, 0, 20, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1, 2, 1, 0, 40, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1, 2, 1, 1, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1, 2, 1, 1, 20, 0, 0, has_year_zero=True)],
#       dtype=object)

# %%
ds_train_input
# Out:
# <xarray.Dataset>
# Dimensions:           (time: 210240, ncol: 384, lev: 60)
# Coordinates:
#   * time              (time) object 0001-02-01 00:00:00 ... 0009-01-31 23:40:00
# Dimensions without coordinates: ncol, lev
# Data variables: (12/27)
#     cam_in_ALDIF      (time, ncol) float64 ...
#     cam_in_ALDIR      (time, ncol) float64 ...
#     cam_in_ASDIF      (time, ncol) float64 ...
#     cam_in_ASDIR      (time, ncol) float64 ...
#     cam_in_ICEFRAC    (time, ncol) float64 ...
#     cam_in_LANDFRAC   (time, ncol) float64 ...
#     ...                ...
#     state_q0001       (time, lev, ncol) float64 ...
#     state_q0002       (time, lev, ncol) float64 ...
#     state_q0003       (time, lev, ncol) float64 ...
#     state_t           (time, lev, ncol) float64 ...
#     state_u           (time, lev, ncol) float64 ...
#     state_v           (time, lev, ncol) float64 ...
# Attributes:
#     calendar:  NO_LEAP
#     fv_nphys:  2
#     ne:        4

# %%
train_x = ds_train_input[['pbuf_LHFLX','state_ps']].resample(time='1M').mean(dim='time')

# %%
mapper = fs.get_mapper('leap-persistent-ro/sungdukyu/E3SM-MMF_ne4.train.output.zarr')
ds_train_output = xr.open_dataset(mapper, engine='zarr')

# %%
# loop over all sample points
year=ds_train_output['ymd']//10000
month=ds_train_output['ymd']%10000//100
day=ds_train_output['ymd']%10000%100
hour=ds_train_output['tod']//3600
minute=ds_train_output['tod']%3600//60

k=0
t = []
for k in range(len(ds_train_output['ymd'])):
    t.append(cftime.DatetimeNoLeap(year[k],month[k],day[k],hour[k],minute[k]))

# add the time array to the 'sample' dimension; then, rename
ds_train_output['sample'] = t
ds_train_output = ds_train_output.rename({'sample':'time'})

# now 'time' dimension replaced 'sample' dimension.
ds_train_output = ds_train_output.drop(['tod','ymd'])

# Check the current **time** dimension, read the timestep
ds_train_output.time.values[0:5]
# Out:
# array([cftime.DatetimeNoLeap(1, 2, 1, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1, 2, 1, 0, 20, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1, 2, 1, 0, 40, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1, 2, 1, 1, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(1, 2, 1, 1, 20, 0, 0, has_year_zero=True)],
#       dtype=object)

# %%
ds_train_output['cam_out_PRECT'] = ds_train_output['cam_out_PRECC'] + ds_train_output['cam_out_PRECSC']
train_y = ds_train_output[['cam_out_PRECT']].resample(time='1M').mean(dim='time')

# %%
train_y
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 96, ncol: 384)
# Coordinates:
#   * time           (time) object 0001-02-28 00:00:00 ... 0009-01-31 00:00:00
# Dimensions without coordinates: ncol
# Data variables:
#     cam_out_PRECT  (time, ncol) float64 1.826e-09 1.298e-08 ... 3.901e-08
# Attributes:
#     calendar:  NO_LEAP
#     fv_nphys:  2
#     ne:        4

# %%
# grid info
mapper = fs.get_mapper("gs://leap-persistent-ro/sungdukyu/E3SM-MMF_ne4.grid-info.zarr")
ds_grid = xr.open_dataset(mapper, engine='zarr')
ds_grid
# Out:
# <xarray.Dataset>
# Dimensions:  (ncol: 384, ilev: 61, lev: 60)
# Dimensions without coordinates: ncol, ilev, lev
# Data variables:
#     P0       float64 ...
#     area     (ncol) float64 ...
#     hyai     (ilev) float64 ...
#     hyam     (lev) float64 ...
#     hybi     (ilev) float64 ...
#     hybm     (lev) float64 ...
#     lat      (ncol) float64 ...
#     lon      (ncol) float64 ...
# Attributes: (12/19)
#     Conventions:       CF-1.7
#     case:              E3SM_ML.GNUGPU.F2010-MMF1.ne4pg2_ne4pg2
#     contact:           e3sm-data-support@listserv.llnl.gov
#     fv_nphys:          2
#     git_version:       4108bd8c11
#     history:           created on 01/13/23 15:30:04
#     ...                ...
#     source:            E3SM Atmosphere Model
#     source_id:         4108bd8c11
#     time_period_freq:  month_1
#     title:             EAM History file information
#     topography_file:   /global/cfs/cdirs/e3sm/inputdata/atm/cam/topo/USGS-gto...
#     username:          sungduk

# %%
print('column number is ',len(np.unique(ds_grid.ncol.values)))
print('if each lat occured in the data can be paired with a lon, the (lat,lon) grid number is', len(np.unique(ds_grid.lat.values))*len(np.unique(ds_grid.lon.values)))
np.unique(ds_grid.lon.values.round(2))
# Out:
# column number is  384
# if each lat occured in the data can be paired with a lon, the (lat,lon) grid number is 17313
# array([  5.63,   5.65,   5.68,   5.73,   6.97,  10.54,  16.89,  16.91,
#         16.96,  17.02,  18.06,  20.4 ,  28.15,  28.2 ,  28.31,  28.47,
#         29.62,  33.28,  39.4 ,  39.46,  39.56,  39.73,  45.  ,  50.27,
#         50.44,  50.54,  50.6 ,  56.72,  60.38,  61.53,  61.69,  61.8 ,
#         61.85,  69.6 ,  71.94,  72.98,  73.04,  73.09,  73.11,  79.46,
#         83.03,  84.27,  84.32,  84.35,  84.37,  95.63,  95.65,  95.68,
#         95.73,  96.97, 100.54, 106.89, 106.91, 106.96, 107.02, 108.06,
#        110.4 , 118.15, 118.2 , 118.31, 118.47, 119.62, 123.28, 129.4 ,
#        129.46, 129.56, 129.73, 135.  , 140.27, 140.44, 140.54, 140.6 ,
#        146.72, 150.38, 151.53, 151.69, 151.8 , 151.85, 159.6 , 161.94,
#        162.98, 163.04, 163.09, 163.11, 169.46, 173.03, 174.27, 174.32,
#        174.35, 174.37, 185.63, 185.65, 185.68, 185.73, 186.97, 190.54,
#        196.89, 196.91, 196.96, 197.02, 198.06, 200.4 , 208.15, 208.2 ,
#        208.31, 208.47, 209.62, 213.28, 219.4 , 219.46, 219.56, 219.73,
#        225.  , 230.27, 230.44, 230.54, 230.6 , 236.72, 240.38, 241.53,
#        241.69, 241.8 , 241.85, 249.6 , 251.94, 252.98, 253.04, 253.09,
#        253.11, 259.46, 263.03, 264.27, 264.32, 264.35, 264.37, 275.63,
#        275.65, 275.68, 275.73, 276.97, 280.54, 286.89, 286.91, 286.96,
#        287.02, 288.06, 290.4 , 298.15, 298.2 , 298.31, 298.47, 299.62,
#        303.28, 309.4 , 309.46, 309.56, 309.73, 315.  , 320.27, 320.44,
#        320.54, 320.6 , 326.72, 330.38, 331.53, 331.69, 331.8 , 331.85,
#        339.6 , 341.94, 342.98, 343.04, 343.09, 343.11, 349.46, 353.03,
#        354.27, 354.32, 354.35, 354.37])

# %%
# original lat and lon info
lat = ds_grid.lat.values.round(2) 
lon = ds_grid.lon.values.round(2) 

# merge the original grid info with the dataset containing atmos variables
ds_multiindex = train_x.copy()
ds_multiindex['lat'] = (('ncol'),lat.T) # (('sample', 'ncol'),lat.T)
ds_multiindex['lon'] = (('ncol'),lon.T)

# set multi-index for the original dataset using lat and lon
ds_multiindex = ds_multiindex.set_index(index_id=["lat", "lon"])
index_id = ds_multiindex.index_id
ds_multiindex = ds_multiindex.drop('index_id')
ds_multiindex = ds_multiindex.rename({'ncol':'index_id'})
ds_multiindex = ds_multiindex.assign_coords(index_id = index_id)
ds_multiindex
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 96, index_id: 384)
# Coordinates:
#   * time        (time) object 0001-02-28 00:00:00 ... 0009-01-31 00:00:00
#   * lat         (index_id) float64 -32.59 -35.99 -22.69 ... 45.34 45.34 40.39
#   * lon         (index_id) float64 320.3 331.5 320.4 331.7 ... 123.3 146.7 135.0
#   * index_id    (index_id) object MultiIndex
# Data variables:
#     pbuf_LHFLX  (time, index_id) float64 43.62 46.79 96.59 ... 3.039 90.37 90.46
#     state_ps    (time, index_id) float64 1.008e+05 1.015e+05 ... 9.983e+04
# Attributes:
#     calendar:  NO_LEAP
#     fv_nphys:  2
#     ne:        4

# %%
# create a dataset with stacked (lat, lon) grids in the original dataset, all values are NaNs
time = train_x.time.values

data_np = np.empty(shape=(len(time), len(np.unique(lat)),len(np.unique(lon))))
data_np[:,:] = np.nan

ds_latlon = xr.Dataset(
     data_vars={
         # v: (("time","index_id"), np.zeros([len(time), len(np.unique(lat))*len(np.unique(lon))]))
         v: (("time","lat","lon"), data_np)
         for v in ['pbuf_LHFLX','state_ps']
     },
     coords={
         "time": train_x.time,
         # "index_id": pd.MultiIndex.from_product(
         #    [np.unique(lat), np.unique(lon)], names=["lat", "lon"],),
         "lat": np.unique(lat),
         "lon": np.unique(lon),
         # "lev": ds.lev,
    },
)

# use multi-index so that we can assign the column data to the (lat,lon) data
ds_latlon = ds_latlon.stack(index_id=['lat','lon'])
ds_latlon 

# print(len(ds_multiindex.index_id.values))
# ds_latlon.sel(index_id=(-32.59, 320.27))
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 96, index_id: 9360)
# Coordinates:
#   * time        (time) object 0001-02-28 00:00:00 ... 0009-01-31 00:00:00
#   * index_id    (index_id) object MultiIndex
#   * lat         (index_id) float64 -82.06 -82.06 -82.06 ... 82.06 82.06 82.06
#   * lon         (index_id) float64 5.63 5.65 5.68 5.73 ... 354.3 354.4 354.4
# Data variables:
#     pbuf_LHFLX  (time, index_id) float64 nan nan nan nan nan ... nan nan nan nan
#     state_ps    (time, index_id) float64 nan nan nan nan nan ... nan nan nan nan

# %%
# use tqdm to visualize the progress of the below loop
# this cell takes about 20min to run, please patiently wait when it is run
latent_heat = ds_latlon.pbuf_LHFLX.copy()
surface_pressure = ds_latlon.state_ps.copy()

for i in (ds_multiindex.index_id.values):
    # ds_latlon.loc[{"index_id": i}] = ds_multiindex[[' cam_out_NETSW','cam_out_PRECC']].sel(index_id = i) 
    #### wrong, will lead to all vars have the same values
    latent_heat.loc[{"index_id": i}] = ds_multiindex['pbuf_LHFLX'].sel(index_id = i)
    surface_pressure.loc[{"index_id": i}] = ds_multiindex['state_ps'].sel(index_id = i)

ds_latlon['pbuf_LHFLX'] = latent_heat.copy()
ds_latlon['state_ps'] = surface_pressure.copy()

ds_unstack = ds_latlon.unstack('index_id')
ds_unstack

## if we directly visualize the 2D maps, then there are many missing values 
fig, ax = plt.subplots(ncols=2, figsize=(12,4))
ds_unstack.pbuf_LHFLX.mean('time').plot(cmap='RdBu_r',ax=ax[0])
ds_unstack.state_ps.mean('time').plot(cmap='RdBu_r',ax=ax[1])

# %%
# original lat and lon info
ncol = train_x.ncol.values

# new lat and lon grids that we finally want
nlat = np.arange(-90, 90.5, 2)
nlon = np.arange(0, 360, 2)

# create a nan-value xr dataset to contain new remapped & interpolated data 
data_var = np.empty([len(time), len(nlat), len(nlon)])
data_var[:,:,:] = np.nan

new_train_x = xr.Dataset(
     data_vars={
         v: (("time","lat","lon"), data_var)
         for v in ['pbuf_LHFLX','state_ps']
     },
     coords={
         "time": train_x.time,
         "lat": nlat,
         "lon": nlon,
        # "lev": ds.lev,
    },
)

new_train_x
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 96, lat: 91, lon: 180)
# Coordinates:
#   * time        (time) object 0001-02-28 00:00:00 ... 0009-01-31 00:00:00
#   * lat         (lat) float64 -90.0 -88.0 -86.0 -84.0 ... 84.0 86.0 88.0 90.0
#   * lon         (lon) int64 0 2 4 6 8 10 12 14 ... 346 348 350 352 354 356 358
# Data variables:
#     pbuf_LHFLX  (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan
#     state_ps    (time, lat, lon) float64 nan nan nan nan nan ... nan nan nan nan

# %%
data_latent_heat = data_var.copy()
data_surface_pressure = data_var.copy()

# interpolate the data using pyngl
# optional: use multiprocessing to save the running time

for it, tt in enumerate(train_x.time):
    data = train_x.sel(time=tt).pbuf_LHFLX.values
    iarr = Ngl.natgrid(lat, lon, data, nlat, nlon) #.squeeze()
    data_latent_heat[it,:] = iarr
    
    data = train_x.sel(time=tt).state_ps.values
    iarr = Ngl.natgrid(lat, lon, data, nlat, nlon) #.squeeze()
    data_surface_pressure[it,:] = iarr

new_train_x['pbuf_LHFLX'].values = data_latent_heat
new_train_x['state_ps'].values = data_surface_pressure

# %%
# plot the maps of these two variables at a specific time step

fig, ax = plt.subplots(ncols=2, figsize=(12,4))
new_train_x['pbuf_LHFLX'].isel(time=10).plot(cmap='RdBu_r',ax=ax[0])
new_train_x['state_ps'].isel(time=10).plot(cmap='RdBu_r',ax=ax[1])
ax[0].set_title('Surface Latent Heat Flux')
ax[1].set_title('Surface Pressure')
# Out:
# Text(0.5, 1.0, 'Surface Pressure')

# %%
new_train_x
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 96, lat: 91, lon: 180)
# Coordinates:
#   * time        (time) object 0001-02-28 00:00:00 ... 0009-01-31 00:00:00
#   * lat         (lat) float64 -90.0 -88.0 -86.0 -84.0 ... 84.0 86.0 88.0 90.0
#   * lon         (lon) int64 0 2 4 6 8 10 12 14 ... 346 348 350 352 354 356 358
# Data variables:
#     pbuf_LHFLX  (time, lat, lon) float64 1.158 1.079 0.5822 ... 34.28 34.46
#     state_ps    (time, lat, lon) float64 8.393e+04 8.382e+04 ... 9.655e+04

# %% [markdown]
# ## Import ds_new as y dataset

# %%
new_train_y = xr.open_dataset('ds_new.nc')

# %%
new_train_y
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 96, lat: 91, lon: 180)
# Coordinates:
#   * time           (time) object 0001-02-28 00:00:00 ... 0009-01-31 00:00:00
#   * lat            (lat) float64 -90.0 -88.0 -86.0 -84.0 ... 84.0 86.0 88.0 90.0
#   * lon            (lon) int64 0 2 4 6 8 10 12 ... 346 348 350 352 354 356 358
# Data variables:
#     cam_out_NETSW  (time, lat, lon) float64 ...
#     cam_out_PRECT  (time, lat, lon) float64 ...

# %% [markdown]
# # Data Preprocessing for NN

# %%
#flattening to 1D array
flatten_x_train = new_train_x.mean(dim = "lon").pbuf_LHFLX.values.flatten()
N = flatten_x_train.shape[0]

#selecting first 6048 values for training data
flatten_x_train[:int(.7*96) * 91].shape

pressure_flatten = new_train_x.mean(dim = "lon").state_ps.values.flatten()
pressure_flatten[:int(.7*96) * 91].shape

flatten_y = new_train_y.mean(dim = "lon").cam_out_PRECT.values.flatten() *3600 *1000
flatten_y[:int(.7*96) * 91].shape
# Out:
# (6097,)

# %%
x_training = pd.DataFrame({"pbuf_LHFLX": flatten_x_train[:int(.7*96) * 91],
                           "state_ps": pressure_flatten[:int(.7*96) * 91]
                          })

x_testing = pd.DataFrame({"pbuf_LHFLX": flatten_x_train[int(.7*96) * 91:],
                           "state_ps": pressure_flatten[int(.7*96) * 91:]
                          })

y_training= pd.DataFrame({"cam_out_PRECT": flatten_y[:int(.7*96) * 91],
                         })

y_testing = pd.DataFrame({"cam_out_PRECT": flatten_y[int(.7*96) * 91:],
                         })

# %%
y_training
# Out:
#       cam_out_PRECT
# 0          0.051791
# 1          0.050457
# 2          0.048846
# 3          0.046823
# 4          0.044775
# ...             ...
# 6092       0.080918
# 6093       0.082260
# 6094       0.083357
# 6095       0.084090
# 6096       0.084565
#
# [6097 rows x 1 columns]

# %%
#data normalization/standardization
X_train_df   = (x_training - x_training.mean())/x_training.std()
X_test_df    = (x_testing - x_testing.mean())/x_testing.std()



X_train = X_train_df.to_numpy()
y_train = y_training.to_numpy()
X_test = X_test_df.to_numpy()
y_test = y_testing.to_numpy()



print(X_train.shape,y_train.shape, X_test.shape,y_test.shape)
# Out:
# (6097, 2) (6097, 1) (2639, 2) (2639, 1)

# %% [markdown]
# # Making NN

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras import Sequential
# Out:
# 2023-06-15 14:37:30.363807: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-15 14:37:30.499515: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# set hyperparameters
n_neuron       = 32
activation     = 'relu'
num_epochs     = 100
learning_rate  = 0.001
minibatch_size = 64
model_num      = 1
N_layers       = 3 # number of hidden layers

# %%
model = Sequential()

model.add(Dense(n_neuron,  activation=activation, name="hidden_layer_1" ,input_shape=(X_train.shape[1],)))
for n in range(N_layers-1):
    model.add(Dense(n_neuron,  activation=activation, name="hidden_layer_"+str(n+2))) 

model.add(Dense(y_train.shape[1],  activation='linear', name="output_layer")) # the output layer
model.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden_layer_1 (Dense)      (None, 32)                96
#
#  hidden_layer_2 (Dense)      (None, 32)                1056
#
#  hidden_layer_3 (Dense)      (None, 32)                1056
#
#  output_layer (Dense)        (None, 1)                 33
#
# =================================================================
# Total params: 2,241
# Trainable params: 2,241
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train and save model

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)


history = model.fit(X_train, y_train, 
                    batch_size      = minibatch_size,
                    epochs          = num_epochs,
                    validation_split= 0.2, 
                    verbose         = 1,
                    callbacks       = [early_stop])
# Out:
# Epoch 1/100
# 77/77 [==============================] - 1s 3ms/step - loss: 0.0061 - val_loss: 0.0027
# Epoch 2/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 3/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 4/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 5/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 6/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 7/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 8/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 9/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 10/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 11/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 12/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 13/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 14/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 15/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 16/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 17/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 18/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 19/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 20/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 21/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 22/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 23/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 24/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 25/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 26/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 27/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 28/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 29/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 30/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 31/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 32/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 33/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 34/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 35/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 36/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 37/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 38/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 39/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 40/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 41/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 42/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 43/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 44/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 45/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 46/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 47/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 48/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 49/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 50/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 51/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 52/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 53/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 54/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 55/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 56/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 57/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 58/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 59/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 60/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 61/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 62/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 63/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 64/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 65/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 66/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 67/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 68/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 69/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 70/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 71/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 72/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 73/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 74/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 75/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 76/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 77/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 78/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 79/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 80/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 81/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 82/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 83/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 84/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 85/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 86/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 87/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 88/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 89/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 90/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 91/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 92/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 93/100
# 77/77 [==============================] - 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 94/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 95/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 96/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 97/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 98/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 99/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 100/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012

# %%
def plot_history(history):
    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean squared error')
    plt.plot(history.epoch, np.array(history.history['loss']),
           label='Train Loss')
    plt.plot(history.epoch, np.array(history.history['val_loss']),
           label = 'Val loss')
    plt.legend()
plot_history(history)

# %%
import os

def make_dir(path):
    if os.path.exists(path) is False:
        os.makedirs(path)

base_dir = os.getcwd()
model_path = os.path.join(base_dir,'saved_model')
make_dir(model_path)

# %%
# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model should be saved to HDF5.
model.save(os.path.join(model_path,'NN_model.h5'))

# %% [markdown]
# # Evaluate saved model

# %%
model = load_model(os.path.join(model_path,'NN_model.h5'))

# %%
y_test_pre = model.predict(X_test)
#y_test_pre = y_test_pre.reshape(y_test_pre.shape[0], 96, 144)

y_test_pre.reshape(96 - int(0.7 * 96), 91)
# Out:
# 83/83 [==============================] - 0s 752us/step
# array([[0.03951745, 0.03885903, 0.03826227, ..., 0.08657772, 0.09208137,
#         0.08944629],
#        [0.03595833, 0.03591626, 0.03596363, ..., 0.08200172, 0.08416042,
#         0.08800364],
#        [0.03667269, 0.03704665, 0.03732347, ..., 0.09084103, 0.09680553,
#         0.0984974 ],
#        ...,
#        [0.03573861, 0.03631721, 0.03688771, ..., 0.08289193, 0.09103891,
#         0.09787844],
#        [0.03792257, 0.03850671, 0.03910335, ..., 0.08415528, 0.09739962,
#         0.10699741],
#        [0.03923029, 0.03957147, 0.03993981, ..., 0.06633597, 0.06477531,
#         0.06461064]], dtype=float32)

# %%
y_truth = y_test.reshape(96 - int(0.7 * 96), 91)
y_prediction = y_test_pre.reshape(96 - int(0.7 * 96), 91)

# %%
plt.plot(y_truth[:,20], label = "truth")
plt.plot(y_prediction[:,20], label = "prediction")
plt.legend()
plt.suptitle("Time Series")
# Out:
# Text(0.5, 0.98, 'Time Series')

# %%
plt.plot(y_truth[28,:], label = "truth")
plt.plot(y_prediction[28,:], label = "prediction")
plt.legend()
plt.suptitle("Across Latitudes")
# Out:
# Text(0.5, 0.98, 'Across Latitudes')
